# %% [markdown]
# <a href="https://colab.research.google.com/github/vendiesel1703-MOH/Project-vault/blob/main/Day_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range(100):
  if (i%10)==0:
    print(i)
  else:
    print("it is not divisble:",i)
# Out:
# 0
# it is not divisble: 1
# it is not divisble: 2
# it is not divisble: 3
# it is not divisble: 4
# it is not divisble: 5
# it is not divisble: 6
# it is not divisble: 7
# it is not divisble: 8
# it is not divisble: 9
# 10
# it is not divisble: 11
# it is not divisble: 12
# it is not divisble: 13
# it is not divisble: 14
# it is not divisble: 15
# it is not divisble: 16
# it is not divisble: 17
# it is not divisble: 18
# it is not divisble: 19
# 20
# it is not divisble: 21
# it is not divisble: 22
# it is not divisble: 23
# it is not divisble: 24
# it is not divisble: 25
# it is not divisble: 26
# it is not divisble: 27
# it is not divisble: 28
# it is not divisble: 29
# 30
# it is not divisble: 31
# it is not divisble: 32
# it is not divisble: 33
# it is not divisble: 34
# it is not divisble: 35
# it is not divisble: 36
# it is not divisble: 37
# it is not divisble: 38
# it is not divisble: 39
# 40
# it is not divisble: 41
# it is not divisble: 42
# it is not divisble: 43
# ...

# %%
def hello():
  print("heelo MOHIT!")

# %%
hello()
# Out:
# heelo MOHIT!
